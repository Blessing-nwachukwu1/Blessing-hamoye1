# %% [markdown]
# <a href="https://colab.research.google.com/github/Blessing-nwachukwu1/Blessing-hamoye1/blob/main/RegHamoye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **importing libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# **Reading the dataset**

# %%
df = pd.read_csv('/content/energydata_complete.csv')
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
df.describe()
# Out:
#          Appliances            T1          RH_1            T2          RH_2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958     21.686571     40.259739     20.341219     40.420420
# std      102.524891      1.606066      3.979299      2.192974      4.069813
# min       10.000000     16.790000     27.023333     16.100000     20.463333
# 25%       50.000000     20.760000     37.333333     18.790000     37.900000
# 50%       60.000000     21.600000     39.656667     20.000000     40.500000
# 75%      100.000000     22.600000     43.066667     21.500000     43.260000
# max     1080.000000     26.260000     63.360000     29.856667     56.026667
#
#                  T3          RH_3            T4          RH_4            T5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      22.267611     39.242500     20.855335     39.026904     19.592106
# ...

# %%
df.shape
# Out:
# (19735, 27)

# %% [markdown]
# **preprocessing**

# %% [markdown]
# To drop the columns lights and date

# %%
df.drop(columns=['date', 'lights'], inplace=True)

# %%
#import train test split
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['Appliances'])
y = df['Appliances']

# %%
# Split the data into training and testing sets (70-30 split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#import the necessary libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# Normalize the features using MinMaxScaler
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# %% [markdown]
# **Q20**

# %%
# Perform multiple regression on the training set
regressor = LinearRegression()
regressor.fit(X_train_normalized, y_train)

# Make predictions on the test set
predictions = regressor.predict(X_test_normalized)

# Calculate mean absolute error
mae = mean_absolute_error(y_test, predictions)

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 53.64297765584956

# %% [markdown]
# **Q21**

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)

# Calculate root mean square error
rmse = np.sqrt(mse)

print("Root Mean Square Error:", rmse)
# Out:
# Root Mean Square Error: 93.64046093998029

# %% [markdown]
# **Q17**

# %%
#select a sample of the dataset
simple_linear_reg_df = df[['T2', 'T6']].sample(15, random_state=42)

# %%
sns.regplot(x="T2", y="T6",
data=simple_linear_reg_df)
# Out:
# <Axes: xlabel='T2', ylabel='T6'>
